# %% [markdown]
# Importando bibliotecas necessárias para o modelo de XGBoost Regressor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# %% [markdown]
# Lendo arquivo .csv (upwork-jobs)

# %%
df = pd.read_csv("upwork-jobs.csv")
df.head()
# Out:
#                                                title  \
# 0  Experienced Media Buyer For Solar Pannel and R...
# 1                               Full Stack Developer
# 2                                    SMMA Bubble App
# 3             Talent Hunter Specialized in Marketing
# 4                                      Data Engineer
#
#                                                 link  \
# 0  https://www.upwork.com/jobs/Experienced-Media-...
# 1  https://www.upwork.com/jobs/Full-Stack-Develop...
# 2  https://www.upwork.com/jobs/SMMA-Bubble-App_%7...
# 3  https://www.upwork.com/jobs/Talent-Hunter-Spec...
# 4  https://www.upwork.com/jobs/Data-Engineer_%7E0...
#
#                                          description  \
# 0  We’re looking for a talented and hardworking a...
# 1  Job Title: Full Stack DeveloperWe are seeking ...
# 2  I need someone to redesign my bubble.io site t...
# 3  Join Our Growing Team!We are an innovative com...
# ...

# %% [markdown]
# Realizando limpeza de valores nulos e filtrando trabalhos por hora

# %%
df = df.dropna(subset=['title', 'description', 'is_hourly', 'hourly_low', 'hourly_high'])
df = df[df['is_hourly'] == True]
df.shape
# Out:
# (22161, 9)

# %% [markdown]
# Criando coluna valor_justo

# %%
df['valor_justo'] = (df['hourly_low'] + df['hourly_high']) / 2
df.head()
# Out:
#                                                 title  \
# 2                                     SMMA Bubble App
# 7   need Portuguese writers who can understand and...
# 13  URGENT: Fix Emails Not Working on Discourse In...
# 15                          Web3 Full-stack Developer
# 18                       Website design, UI/UX Design
#
#                                                  link  \
# 2   https://www.upwork.com/jobs/SMMA-Bubble-App_%7...
# 7   https://www.upwork.com/jobs/need-Portuguese-wr...
# 13  https://www.upwork.com/jobs/URGENT-Fix-Emails-...
# 15  https://www.upwork.com/jobs/Web3-Full-stack-De...
# 18  https://www.upwork.com/jobs/Website-design-Des...
#
#                                           description  \
# 2   I need someone to redesign my bubble.io site t...
# 7   Portuguese writers who have a deep understandi...
# 13  URGENTQuick job for a Discourse Forum expert.T...
# 15  We are looking for a Web3 full-stack developer...
# ...

# %% [markdown]
# Limpando outliers

# %%
Q1 = df['valor_justo'].quantile(0.25)
Q3 = df['valor_justo'].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

df = df[(df['valor_justo'] >= limite_inferior) & (df['valor_justo'] <= limite_superior)]
print(f"Após remoção de outliers: {df.shape[0]} linhas restantes")
# Out:
# Após remoção de outliers: 20736 linhas restantes

# %% [markdown]
# Juntando título e descrição

# %%
df['texto'] = df['title'] + " " + df['description']

# %% [markdown]
# Divisão dos dados entre treinamento e teste

# %%
X = df[['texto']]
y = df['valor_justo']
X_train, X_test, y_train, y_test = train_test_split(X['texto'], y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (16588,)

# %%
X_test.shape
# Out:
# (4148,)

# %% [markdown]
# Vetorização TF-IDF

# %%
vectorizer = TfidfVectorizer(max_features=10000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %% [markdown]
# Treinando o modelo XGBoost Regressor

# %%
xgb_model = XGBRegressor(n_estimators=100, random_state=42, verbosity=0)
xgb_model.fit(X_train_tfidf, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Realizando previsões

# %%
y_pred = xgb_model.predict(X_test_tfidf)

# %% [markdown]
# Avaliando desempenho do modelo

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"R²: {r2:.4f}")
# Out:
# RMSE: 7.16
# MAE: 4.82
# R²: 0.7493

# %% [markdown]
# Visualização das previsões

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')
plt.xlabel("Valor Real por Hora")
plt.ylabel("Valor Previsto por Hora")
plt.title("XGBoost - Valor Justo por Hora")
plt.grid(True)
plt.show()

# %% [markdown]
# Salvando o modelo e vetorizador com Pickle

# %%
with open('modelo_xgboost_valor_hora.pkl', 'wb') as file:
    pickle.dump(xgb_model, file)

with open('tfidf_vectorizer_valor_hora.pkl', 'wb') as file:
    pickle.dump(vectorizer, file)

print("Modelo XGBoost e vetorizador TF-IDF para valor por hora salvos com sucesso!")
# Out:
# Modelo XGBoost e vetorizador TF-IDF para valor por hora salvos com sucesso!
